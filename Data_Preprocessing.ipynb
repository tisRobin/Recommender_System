# %% [markdown]
# <a href="https://colab.research.google.com/github/tisRobin/Recommender_System/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The Dataset
#
# https://osf.io/3uw9d/

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import numpy as np
import pandas as pd

# %%
participant = pd.read_csv('/content/gdrive/MyDrive/Group 3/Data/K-pop songs Dataset/Data 1 - raw-participant.csv',  encoding='cp949')

# %%
participant = participant[participant['song_country'] == 'KR']
participant
# Out:
#       rater_nationality   participant_id           stimID repeated_trial  \
# 0              American  participant_US1  KR-2014-block11              f
# 1              American  participant_US1  KR-2013-block11              f
# 5              American  participant_US1  KR-2012-block11              f
# 7              American  participant_US3  KR-2018-block11              f
# 10             American  participant_US3  KR-2015-block11              f
# ...                 ...              ...              ...            ...
# 11490         Brazilian  participant_BR6   KR-2013-block5              f
# 11491         Brazilian  participant_BR6   KR-2015-block5              f
# 11492         Brazilian  participant_BR6   KR-2011-block5              f
# 11494         Brazilian  participant_BR6   KR-2017-block5              f
# 11499         Brazilian  participant_BR6   KR-2019-block5              f
#
#       song_country  song_year singer_gender  preference_5pt  familiarity_4pt  \
# 0               KR       2014             m               4                1
# 1               KR       2013             f               1                1
# 5               KR       2012             f               5                1
# 7               KR       2018             m               2                1
# 10              KR       2015             m               3                1
# ...            ...        ...           ...             ...              ...
# 11490           KR       2013             m               2                1
# 11491           KR       2015             f               3                1
# 11492           KR       2011             f               1                1
# 11494           KR       2017             f               3                1
# 11499           KR       2019             f               2                1
#
#        calm  tense  cheerful  sad  danceable  love  dreamy  electronic  energy
# 0         1      1         4    1          4     4       4           4       4
# 1         2      1         4    1          4     4       2           3       4
# 5         2      1         2    2          3     4       4           2       3
# 7         2      2         1    3          1     2       2           1       2
# 10        1      1         3    1          2     2       2           3       2
# ...     ...    ...       ...  ...        ...   ...     ...         ...     ...
# 11490     2      1         2    1          2     1       1           2       2
# 11491     2      1         2    1          3     3       2           2       2
# 11492     2      3         1    3          1     1       1           1       1
# 11494     2      1         2    1          2     1       2           2       2
# 11499     2      1         1    1          2     1       1           2       2
#
# [3845 rows x 18 columns]

# %%
KR_song = pd.read_csv('/content/gdrive/MyDrive/Group 3/Data/K-pop songs Dataset/Data 2 - song_chart.csv',  encoding = 'utf-8')

# %%
KR_song
# Out:
#     song_origin chart_source  year           stimID  \
# 0           KOR   Gaon Chart  2010   KR-2010-block1
# 1           KOR   Gaon Chart  2010   KR-2010-block2
# 2           KOR   Gaon Chart  2010   KR-2010-block3
# 3           KOR   Gaon Chart  2010   KR-2010-block4
# 4           KOR   Gaon Chart  2010   KR-2010-block5
# ..          ...          ...   ...              ...
# 355         BRA      Crowley  2019   BR-2019-block8
# 356         BRA      Crowley  2019   BR-2019-block9
# 357         BRA      Crowley  2019  BR-2019-block10
# 358         BRA      Crowley  2019  BR-2019-block11
# 359         BRA      Crowley  2019  BR-2019-block12
#
#                           song_query                   artist_query  \
# 0                          Here I Am                   포맨 (4men), 美
# 1                          밤하늘의 별을..    양정승 (kiroy Y), Kcm & No Noo
# 2                                  Y                    엠블랙 (mblaq)
# 3                            사랑한다는 말                            남규리
# 4    사랑, 우정 그리고… (with No Noo & 양정승)                       제이비 (jb)
# ..                               ...                            ...
# 355                 Saudade Infinita                Roberta Miranda
# 356                          Combate                          Um44k
# 357                   Salvou Meu Dia  Mc Kevinho Part.Gusttavo Lima
# 358                       500 Metros  Paula Mattos Part.Lucas Lucco
# 359                 Toquin Do Violao                   Sandro Cesar
#
#                                    song_result_spotify  \
# 0                                            Here I am
# 1                                            밤하늘의 별을..
# 2                                                    Y
# 3                                              사랑한다는 말
# 4                                          사랑, 우정 그리고…
# ..                                                 ...
# 355                                   Saudade Infinita
# 356                                            Combate
# 357  Salvou meu dia (Participação especial de Gustt...
# 358  500 metros (Participação especial de Lucas Lucco)
# 359                                   Toquin do Violão
#
#          artist_result_spotify         spotify_trackid  \
# 0                         4MEN  2HeHipLSY7SWKLjsZdUbjQ
# 1                      Kiroy Y  3zNyjuCpWig3iYWs9PgbDM
# 2                        MBLAQ  3xVGwwax3gAPAkJewnB2eZ
# 3                   Nam Gyu ri  1o68HIqheZWvKk4m9DnCK0
# 4                           JB  2ovX90glSOm2ouAIhtV3gB
# ..                         ...                     ...
# 355            Roberta Miranda  6J2ySKkqPkB0oB2IaqYO1e
# 356                      UM44K  2gV8yu7sEnewmsVa4CnbOG
# 357  MC Kevinho, Gusttavo Lima  7CBImG41isOs2r7lQU7CCy
# 358  Paula Mattos, Lucas Lucco  2mo6GXEG5IwAA8CfBViGAf
# 359               Sandro César  1qrrjgSAnpuw8Pf2NTr5eN
#
#                                            preview.url  ... loudness  mode  \
# 0    https://p.scdn.co/mp3-preview/8e5d94375aa154f3...  ...   -7.834     1
# 1    https://p.scdn.co/mp3-preview/0a34821c26bbafb2...  ...   -4.578     1
# 2    https://p.scdn.co/mp3-preview/c9e9462cf7b31162...  ...   -4.828     0
# 3    https://p.scdn.co/mp3-preview/e0a64b47cc65954b...  ...   -7.516     1
# 4    https://p.scdn.co/mp3-preview/836553176e549f53...  ...   -6.121     1
# ..                                                 ...  ...      ...   ...
# 355  https://p.scdn.co/mp3-preview/e96bd3f00838fbf2...  ...   -6.369     1
# 356  https://p.scdn.co/mp3-preview/76335d9d17acdd5e...  ...   -6.116     1
# 357  https://p.scdn.co/mp3-preview/cbcc7edf512a1508...  ...   -2.688     0
# 358  https://p.scdn.co/mp3-preview/55f5b6b3309ab5ec...  ...   -3.862     1
# 359  https://p.scdn.co/mp3-preview/f9c44e7fd9407fa1...  ...   -3.283     1
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0         0.0335        0.8540          0.000000    0.1030    0.101  129.552
# 1         0.0609        0.2410          0.000001    0.1160    0.406  153.807
# 2         0.1420        0.0298          0.000004    0.0967    0.875  122.952
# 3         0.0372        0.8130          0.000000    0.1110    0.172  134.063
# 4         0.0336        0.8170          0.000000    0.1090    0.499  171.757
# ..           ...           ...               ...       ...      ...      ...
# 355       0.0274        0.2240          0.000000    0.1250    0.582  105.960
# 356       0.1450        0.3150          0.000000    0.0974    0.831   88.040
# 357       0.0807        0.4090          0.000000    0.3260    0.830  162.077
# 358       0.0510        0.6190          0.000000    0.1060    0.686  123.872
# 359       0.0699        0.3630          0.000000    0.0928    0.735  147.880
#
#      duration_ms  time_signature
# 0         235563               4
# 1         225787               4
# 2         208523               4
# 3         248099               4
# 4         218906               4
# ..           ...             ...
# 355       194893               4
# 356       179253               4
# 357       163666               4
# 358       175326               4
# 359       167211               4
#
# [360 rows x 24 columns]

# %%
song_pref = pd.merge(participant, KR_song, how = 'left', on = 'stimID')

# %%
song_pref.columns
# Out:
# Index(['rater_nationality', 'participant_id', 'stimID', 'repeated_trial',
#        'song_country', 'song_year', 'singer_gender', 'preference_5pt',
#        'familiarity_4pt', 'calm', 'tense', 'cheerful', 'sad', 'danceable',
#        'love', 'dreamy', 'electronic', 'energy_x', 'song_origin',
#        'chart_source', 'year', 'song_query', 'artist_query',
#        'song_result_spotify', 'artist_result_spotify', 'spotify_trackid',
#        'preview.url', 'ISRC', 'danceability', 'energy_y', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
ratings = song_pref[["participant_id", "song_query", "preference_5pt"]]
ratings
# Out:
#        participant_id         song_query  preference_5pt
# 0     participant_US1            Thunder               4
# 1     participant_US1            그녀의 사무실               1
# 2     participant_US1                사랑아               5
# 3     participant_US3                영원히               2
# 4     participant_US3             너를 그리다               3
# ...               ...                ...             ...
# 3840  participant_BR6  만약에 말야 (전우성 Solo)               2
# 3841  participant_BR6  Wifey (feat. Mc몽)               3
# 3842  participant_BR6           Break Up               1
# 3843  participant_BR6             낡은 그리움               3
# 3844  participant_BR6              Flash               2
#
# [3845 rows x 3 columns]

# %%
ratings.to_csv('/content/gdrive/MyDrive/Group 3/Data/K-pop songs Dataset/Ratings.csv', index = None, header=True )
